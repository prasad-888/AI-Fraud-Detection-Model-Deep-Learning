# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Prasad\Desktop\secure-bank-fraud-ml\data\paysim_eda_processed.csv")

# %%
df.head(10)
# Out:
#      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  newbalanceDest  \
# 0   9839.64      170136.00       160296.36             0.0            0.00
# 1   1864.28       21249.00        19384.72             0.0            0.00
# 2    181.00         181.00            0.00             0.0            0.00
# 3    181.00         181.00            0.00         21182.0            0.00
# 4  11668.14       41554.00        29885.86             0.0            0.00
# 5   7817.71       53860.00        46042.29             0.0            0.00
# 6   7107.77      183195.00       176087.23             0.0            0.00
# 7   7861.64      176087.23       168225.59             0.0            0.00
# 8   4024.36        2671.00            0.00             0.0            0.00
# 9   5337.77       41720.00        36382.23         41898.0        40348.79
#
#    isFraud  isFlaggedFraud  hour_of_day  day  log1p_amount  \
# 0        0               0            0    0      9.194276
# ...

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (6362620, 18)

# %%
from sklearn.model_selection import train_test_split

X = df.drop('isFraud', axis=1)
y = df['isFraud']

# %%
x_sample, _, y_sample, _ = train_test_split(
    X, y,
    test_size=0.9,
stratify=y,
    random_state = 42
)

# %%
x_sample['isFraud'] = y_sample

# %%
x_sample.to_csv(r"C:\Users\Prasad\Desktop\secure-bank-fraud-ml\data\paysim_model_ready.csv", index=False)

# %%
x_sample.shape
# Out:
# (636262, 18)
